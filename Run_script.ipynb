# %%
import os

CUDA_ROOT = "/home/shauryas23/miniconda3"

os.environ["CUDA_HOME"] = CUDA_ROOT
os.environ["CUDA_PATH"] = CUDA_ROOT
os.environ["CUDA_NVRTC_LIBDEVICE_PATH"] = f"{CUDA_ROOT}/nvvm/libdevice"
os.environ["NVVMIR_LIBRARY_DIR"] = f"{CUDA_ROOT}/nvvm/libdevice"
os.environ["PATH"] = f"{CUDA_ROOT}/bin:" + os.environ.get("PATH", "")

print("CUDA env set")
# Out:
# CUDA env set

# %%
import os
print(os.environ["CUDA_NVRTC_LIBDEVICE_PATH"])
print(os.listdir(os.environ["CUDA_NVRTC_LIBDEVICE_PATH"]))
# Out:
# /home/shauryas23/miniconda3/nvvm/libdevice
# ['libdevice.10.bc']

# %%
import ctypes
ctypes.CDLL("libnvrtc.so")
print("NVRTC loaded")
# Out:
# NVRTC loaded

# %%
import os
print("CUDA_NVRTC_LIBDEVICE_PATH =", os.environ.get("CUDA_NVRTC_LIBDEVICE_PATH"))
print("Files:", os.listdir(os.environ["CUDA_NVRTC_LIBDEVICE_PATH"]))
# Out:
# CUDA_NVRTC_LIBDEVICE_PATH = /home/shauryas23/miniconda3/nvvm/libdevice
# Files: ['libdevice.10.bc']

# %%
# %run code_HENM.py "/home/shauryas23/Downloads/40CG_MSPA_298K" "xtc"
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# read the trajectory
# calculate MD fluctuation start
# end
# The number of bonds in run 1 780
# MD OVER
# flag_identical_bonds=no
# w_old: [327.88914284 291.63994283 283.1647746  279.54524727 271.97987026
#  261.68086732 258.11313543 249.06911364 246.92795324 241.19479574
#  234.42179165 231.75086539 230.50409389 225.13101209 223.39415746
#  221.30759512 217.86711154 218.08951282 214.31280648 209.4370768
#  211.12715783 205.86078032 204.36892598 201.84770718 199.73048045
#  198.01649373 194.94086572 190.47905736 185.24714482 180.98925098
#  173.12183404 174.00704723 170.6286714  166.75366689 167.49744349
#  161.44391957 159.12236073 158.60655857 154.71118372 155.51847676
#  148.69843998 146.10905586 143.10163776  12.45117923  12.75168126
# ...

# %%
print("bond_list[:, 2] :", bond_list[:, 2]/4.184)
# Out:
# bond_list[:, 2] : [0.008687458523261811 0.09564067125718644 0.03359028158811814
#  0.09113638317994152 0.03340378805312331 0.013963451993869332
#  28.56192023312559 0.07295841524723963 0.0458458661824141
#  0.011976925093632167 0.002926790014534309 0.22183038246292378
#  0.07240881959408167 59.97209378625921 0.017509506793285255
#  27.33062092504836 20.606354186759944 20.344499831914625
#  19.773950413931626 10.38510948224333 0.0014001260497418248
#  58.402597650712444 22.25043969290115 20.868442519632154
#  0.0112969649105915 2.202016889256924 25.106153153111205
#  1.8842427284278813 0.030209311779409893 34.169173231226516
#  0.0013758115174632344 0.0806867468904734 17.909176692392766
#  0.05629995072681401 4.121657156640669 0.00763038571204437
#  84.21619046301092 15.397927715613879 7.472883867843751 30.86215522421075
#  0.0894865149351388 0.002390057361376673 1.725325594201271
#  0.11552033615478734 0.04834191693535242 0.29379890147660104
# ...

# %%
# %run post_henm.py "/home/shauryas23/Downloads/40CG_MSPA_298K" "xtc"
# %run code_HENM.py "C:\Users\HHK LAB\Documents\MSPA_NEW_NR\MSPA_184CG_28_9_25_298K_aligned_mwt\HENM" "lammpstrj" "no" "HENM"
